# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import math

# %% [markdown]
# ### API words

# %%
def remove_punctuation(text):
    special_punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    for ele in text:
        if ele in special_punc:
            text = text.replace(ele, "")
    return text

# %%
def remove_stopwords(text):
    text_tokens = word_tokenize(text)
    tokens_without_sw = ' '.join([word for word in text_tokens if not word in stopwords.words()])
    return tokens_without_sw

# %%
def stem(text):
    try:
        ps = PorterStemmer()
        return ps.stem(text)
    except:
        return text

# %%
def split_and_concat(df):
    dicte={}
    IDs=df['ID'].tolist()
    for ID in tqdm(IDs):
        df_del=df[df['ID']==ID]
        df_del=df_del.reset_index(drop=True)
        df_del['original_word']=df_del['ENGLISH'][0]
        df_del=df_del.reset_index(drop=True)
        list_words=df_del['ENGLISH'][0].split()
        for word in list_words:    
            df_del=df_del.append({'original_word':df_del['ENGLISH'][0],'ID':df_del['ID'][0],'FRENCH':df_del['FRENCH'][0],'ENGLISH':word,'THEME':df_del['THEME'][0],'IMPORTANT':df_del['IMPORTANT'][0]},ignore_index=True)
        df_del=df_del.drop(0)
        dicte[ID]=df_del

    df_new=pd.concat(dicte)
    df_new=df_new.reset_index(drop=True)
    return df_new

# %%
df=pd.read_csv('inputs/data.csv')

# %%
df_new=split_and_concat(df)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8382/8382 [01:36<00:00, 86.87it/s]

# %%
df_new['ENGLISH_stem']=df_new['ENGLISH'].apply(remove_punctuation).apply(stem)

# %%
df_new=df_new[df_new.ENGLISH_stem.notna()]

# %% [markdown]
# ### Occurences 2

# %%
df4=pd.read_csv('WikiWords_FirstMillion_Refined_V6.csv')
df4.columns=['ENGLISH','OCCURENCES']
df4=df4[df4['ENGLISH'].notna()]
df4=df4.drop_duplicates(subset=['ENGLISH'])

# %%
df4_new=df4.copy()
df4_new['ENGLISH_stem']=df4_new['ENGLISH'].apply(stem)
df4_new=df4_new.drop_duplicates(subset=['ENGLISH_stem'])

# %% [markdown]
# ### Merge 2

# %%
df5_new=df_new.merge(df4_new,how='outer',left_on=['ENGLISH_stem'],right_on=['ENGLISH_stem'])

# %%
df5_new[(df5_new['FRENCH'].notna())&(df5_new['OCCURENCES'].notna())]
# Out:
#            ID                   FRENCH ENGLISH_x                  THEME  \
# 0         1.0                 accepter        to  verbes a connaitre en
# 1         2.0                  acheter        to  verbes a connaitre en
# 2         3.0                    aider        to  verbes a connaitre en
# 3         4.0                    aimer        to  verbes a connaitre en
# 4         4.0                    aimer        to  verbes a connaitre en
# ...       ...                      ...       ...                    ...
# 17740  8362.0      une nouvelle souche    strain      covid coronavirus
# 17741  8373.0                  intuber  intubate      covid coronavirus
# 17742  8374.0                   isoler   isolate      covid coronavirus
# 17743  8378.0  reporter des événements  postpone      covid coronavirus
# 17744  8382.0  transmettre une maladie  transmit      covid coronavirus
#
#        IMPORTANT          original_word ENGLISH_stem    ENGLISH_y  OCCURENCES
# 0            NaN              to accept           to           to   6032733.0
# 1            NaN                 to buy           to           to   6032733.0
# 2            NaN                to help           to           to   6032733.0
# 3            NaN       to like/ to love           to           to   6032733.0
# 4            NaN       to like/ to love           to           to   6032733.0
# ...          ...                    ...          ...          ...         ...
# 17740        NaN           a new strain       strain       strain       160.0
# 17741        NaN            to intubate        intub   intubation         1.0
# 17742        NaN             to isolate         isol     isolated       234.0
# 17743        NaN     to postpone events      postpon    postponed       239.0
# 17744        NaN  to transmit a disease     transmit  transmitted       181.0
#
# [17089 rows x 9 columns]

# %%
IDS_doubt=df5_new[(df5_new['FRENCH'].notna())&(df5_new['OCCURENCES'].isna())].ID.unique().tolist()

# %%
str(round(len(IDS_doubt)/len(df)*100,2))+'%'
# Out:
# '7.59%'

# %%
df_final=df5_new[(df5_new['FRENCH'].notna())&(df5_new['OCCURENCES'].notna())&(~df5_new.ID.isin(IDS_doubt))]
df_final=df_final[['ID','FRENCH','original_word','THEME','ENGLISH_x','OCCURENCES']].sort_values(by=['ID'])
df_final=df_final.groupby(['ID']).min()
df_final['ID']=df_final.index
df_final=df_final.reset_index(drop=True)
df_final=df_final.sort_values(by=['ID'])
df_final['ENGLISH']=df_final['original_word']
df_final=df_final.drop(columns=['original_word'])

# %%
df_final
# Out:
#                        FRENCH                  THEME ENGLISH_x  OCCURENCES  \
# 0                    accepter  verbes a connaitre en    accept      2123.0
# 1                     acheter  verbes a connaitre en       buy       547.0
# 2                       aider  verbes a connaitre en      help      1629.0
# 3                       aimer  verbes a connaitre en     like/      4224.0
# 4                     ajouter  verbes a connaitre en       add    121636.0
# ...                       ...                    ...       ...         ...
# 7741  reporter des événements      covid coronavirus    events       239.0
# 7742          restez chez soi      covid coronavirus        at     20497.0
# 7743        se faire vacciner      covid coronavirus   receive       111.0
# 7744      tester les patients      covid coronavirus  patients       194.0
# 7745  transmettre une maladie      covid coronavirus         a       181.0
#
#           ID                 ENGLISH
# 0        1.0               to accept
# 1        2.0                  to buy
# 2        3.0                 to help
# 3        4.0        to like/ to love
# 4        5.0                  to add
# ...      ...                     ...
# 7741  8378.0      to postpone events
# 7742  8379.0         to stay at home
# 7743  8380.0  to receive the vaccine
# 7744  8381.0        to test patients
# 7745  8382.0   to transmit a disease
#
# [7746 rows x 6 columns]

# %%
len(df_final)
# Out:
# 7746

# %%
df_final['_interval']=pd.qcut(df_final['OCCURENCES'],100,duplicates='drop')

# %%
df_final['INTERVAL']=pd.qcut(df_final['OCCURENCES'],100,duplicates='drop',labels=False)

# %%
df_final['INTERVAL']=100-df_final['INTERVAL']

# %%
df_final
# Out:
#                        FRENCH                  THEME ENGLISH_x  OCCURENCES  \
# 0                    accepter  verbes a connaitre en    accept      2123.0
# 1                     acheter  verbes a connaitre en       buy       547.0
# 2                       aider  verbes a connaitre en      help      1629.0
# 3                       aimer  verbes a connaitre en     like/      4224.0
# 4                     ajouter  verbes a connaitre en       add    121636.0
# ...                       ...                    ...       ...         ...
# 7741  reporter des événements      covid coronavirus    events       239.0
# 7742          restez chez soi      covid coronavirus        at     20497.0
# 7743        se faire vacciner      covid coronavirus   receive       111.0
# 7744      tester les patients      covid coronavirus  patients       194.0
# 7745  transmettre une maladie      covid coronavirus         a       181.0
#
#           ID                 ENGLISH             _interval  INTERVAL
# 0        1.0               to accept      (1990.0, 2160.0]        15
# 1        2.0                  to buy        (546.0, 576.0]        32
# 2        3.0                 to help      (1520.0, 1652.2]        18
# 3        4.0        to like/ to love      (4142.2, 4620.7]         9
# 4        5.0                  to add  (65303.7, 1466432.0]         2
# ...      ...                     ...                   ...       ...
# 7741  8378.0      to postpone events        (232.0, 247.0]        47
# 7742  8379.0         to stay at home    (14096.5, 23200.9]         4
# 7743  8380.0  to receive the vaccine        (109.0, 115.0]        60
# 7744  8381.0        to test patients        (184.0, 196.0]        51
# 7745  8382.0   to transmit a disease        (175.0, 184.0]        52
#
# [7746 rows x 8 columns]

# %%
df_final.sort_values(by=['INTERVAL'])
# Out:
#                   FRENCH                     THEME  ENGLISH_x  OCCURENCES  \
# 3646           les pages        journalisme presse      pages   1111264.0
# 4181                août        jours mois saisons     august     76147.0
# 1585          une erreur        education et ecole          a    108429.0
# 74            ressembler     verbes a connaitre en       like    448270.0
# 545                  usé   adjectifs essentiels en       used    121228.0
# ...                  ...                       ...        ...         ...
# 2100          pulvériser            guerre et paix  pulverize         1.0
# 2115              trahir            guerre et paix     betray         2.0
# 4592  une cocotte minute        ustensiles cuisine          a         2.0
# 7358           marmonner  par theme langage parole     mumble         2.0
# 1274          anorexique       decrire quelquun en   anorexic         1.0
#
#           ID            ENGLISH             _interval  INTERVAL
# 3646  3851.0              pages  (65303.7, 1466432.0]         2
# 4181  4430.0             august  (65303.7, 1466432.0]         2
# 1585  1668.0          a mistake  (65303.7, 1466432.0]         2
# 74      75.0       to look like  (65303.7, 1466432.0]         2
# 545    554.0               used  (65303.7, 1466432.0]         2
# ...      ...                ...                   ...       ...
# 2100  2212.0       to pulverize          (0.999, 2.0]       100
# 2115  2227.0          to betray          (0.999, 2.0]       100
# 4592  4927.0  a pressure cooker          (0.999, 2.0]       100
# 7358  7955.0          to mumble          (0.999, 2.0]       100
# 1274  1324.0           anorexic          (0.999, 2.0]       100
#
# [7746 rows x 8 columns]

# %%
df_final['INTERVAL'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df_final.to_csv('output/data.csv',index=False)
